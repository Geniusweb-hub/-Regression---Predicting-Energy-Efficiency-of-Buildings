# %% [markdown]
# # importing necessary libraries

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression,Ridge,Lasso

# %% [markdown]
# ### Reading csv file

# %%
df = pd.read_csv(r"/All data/energy_data.csv")
df
# Out:
#                       date  Appliances  lights         T1       RH_1  \
# 0      2016-01-11 17:00:00          60      30  19.890000  47.596667
# 1      2016-01-11 17:10:00          60      30  19.890000  46.693333
# 2      2016-01-11 17:20:00          50      30  19.890000  46.300000
# 3      2016-01-11 17:30:00          50      40  19.890000  46.066667
# 4      2016-01-11 17:40:00          60      40  19.890000  46.333333
# ...                    ...         ...     ...        ...        ...
# 19730  2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731  2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732  2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733  2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734  2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3         T4  ...         T9  \
# ...

# %% [markdown]
# # Renaming the columns

# %%
#column_names = { "T1":"Temperature in kitchen area","RH_1":"Humidity in kitchen area", "T2":"Temperature in living room area","RH_2":"Humidity in living room area",
#"T3":"Temperature in laundry room area", "RH_3":"Humidity in laundry room area", "T4":"Temperature in office room", "RH_4":"Humidity in office room",
#"T5":"Temperature in bathroom", "RH_5":"Humidity in bathroom", "T6":"Temperature outside the building_north side", "RH_6":"Humidity outside the building_north side",
#"T7":"Temperature in ironing room", "RH_7":"Humidity in ironing room", "T8":"Temperature in teenager room 2", "RH_8":"Humidity in teenager room 2",
#"T9":"Temperature in parents room", "RH_9":"Humidity in parents room","T_out":"Temperature outside_from Chievres weather station",
#"press_mm_hg":"Pressure_from Chievres weather station", "RH_out":"Humidity outside_from Chievres weather station",
#"Windspeed":"Wind speed_from Chievres weather station","Visibility":"Visibility_from Chievres weather station", "Tdewpoint":"Tdewpoint_from Chievres weather station",
#"rv1":"Random variable 1", "rv2":"Random variable 2"}
#df = df.rename(columns=column_names) 
df
# Out:
#        date  Appliances  lights         T1       RH_1         T2       RH_2  \
# 0       NaN          60      30  19.890000  47.596667  19.200000  44.790000
# 1       NaN          60      30  19.890000  46.693333  19.200000  44.722500
# 2       NaN          50      30  19.890000  46.300000  19.200000  44.626667
# 3       NaN          50      40  19.890000  46.066667  19.200000  44.590000
# 4       NaN          60      40  19.890000  46.333333  19.200000  44.530000
# ...     ...         ...     ...        ...        ...        ...        ...
# 19730   NaN         100       0  25.566667  46.560000  25.890000  42.025714
# 19731   NaN          90       0  25.500000  46.500000  25.754000  42.080000
# 19732   NaN         270      10  25.500000  46.596667  25.628571  42.768571
# 19733   NaN         420      10  25.500000  46.990000  25.414000  43.036000
# 19734   NaN         430      10  25.500000  46.600000  25.264286  42.971429
#
# ...

# %%
print("Keys of df: \n{}".format(df.keys()))
# Out:
# Keys of df:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %%
df.shape
# Out:
# (19735, 29)

# %%
df.dtypes.value_counts()
# Out:
# float64    26
# int64       2
# object      1
# dtype: int64

# %%
df.dtypes == "object"
# Out:
# date            True
# Appliances     False
# lights         False
# T1             False
# RH_1           False
# T2             False
# RH_2           False
# T3             False
# RH_3           False
# T4             False
# RH_4           False
# T5             False
# RH_5           False
# T6             False
# RH_6           False
# T7             False
# RH_7           False
# T8             False
# RH_8           False
# T9             False
# RH_9           False
# T_out          False
# Press_mm_hg    False
# RH_out         False
# Windspeed      False
# Visibility     False
# Tdewpoint      False
# rv1            False
# rv2            False
# dtype: bool

# %% [markdown]
# # Converting date from objects to float

# %%
df["date"] = pd.to_numeric(df["date"], errors="coerce")

# %% [markdown]
# # normalizing and removing "date" and "lights" columns

# %%
normalised_df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
features_df   =   normalised_df.drop(columns=[ 'date' ,'lights' ])
features_df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:375: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:376: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)
#        Appliances        T1      RH_1        T2      RH_2        T3      RH_3  \
# 0        0.046729  0.327350  0.566187  0.225345  0.684038  0.215188  0.746066
# 1        0.046729  0.327350  0.541326  0.225345  0.682140  0.215188  0.748871
# 2        0.037383  0.327350  0.530502  0.225345  0.679445  0.215188  0.755569
# 3        0.037383  0.327350  0.524080  0.225345  0.678414  0.215188  0.758685
# 4        0.046729  0.327350  0.531419  0.225345  0.676727  0.215188  0.758685
# ...           ...       ...       ...       ...       ...       ...       ...
# 19730    0.084112  0.926786  0.537657  0.711655  0.606309  0.830841  0.579374
# ...

# %% [markdown]
# # normalizing the data to a common scale using min max scaler

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()  
energy_target = normalised_df['Appliances'] 
energy_target
# Out:
# 0        0.046729
# 1        0.046729
# 2        0.037383
# 3        0.037383
# 4        0.046729
#            ...
# 19730    0.084112
# 19731    0.074766
# 19732    0.242991
# 19733    0.383178
# 19734    0.392523
# Name: Appliances, Length: 19735, dtype: float64

# %% [markdown]
# # Splitting the data into training and testing dataset

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features_df, energy_target, test_size=0.3, random_state=42)

# %% [markdown]
# # printing the shape of the training and testing dataset

# %%
print("X_train shape: {}".format(X_train.shape)) 
print("y_train shape: {}".format(y_train.shape))
print("X_test shape: {}".format(X_test.shape)) 
print("y_test shape: {}".format(y_test.shape))
#X_test.shape
#y_test.shape
# Out:
# X_train shape: (13814, 27)
# y_train shape: (13814,)
# X_test shape: (5921, 27)
# y_test shape: (5921,)

# %% [markdown]
# # Creating a model and fitting it

# %%
linear_model = LinearRegression() 
linear_model.fit(X_train, y_train)
linear_model = LinearRegression().fit(X_train, y_train)
linear_model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# # Obtaining results

# %%
r_sq = linear_model.score(X_train, y_train)
print('coefficient of determination:', r_sq)
print('intercept:', linear_model.intercept_) 
print('slope:', linear_model.coef_)
# Out:
# coefficient of determination: 1.0
# intercept: -1.6375789613221059e-15
# slope: [ 1.00000000e+00 -6.18562872e-16  6.94409707e-16 -3.40289469e-16
#  -9.63729569e-16  2.01063031e-16  2.33015433e-16  6.09421014e-17
#  -1.42608686e-16 -1.96532353e-16 -6.66601431e-17 -3.67073964e-16
#   2.50011067e-16 -6.51344834e-16  6.94531944e-16  5.38034948e-16
#  -7.26549585e-16  2.36591992e-16 -1.38427121e-17  8.06947587e-16
#  -1.18897316e-16  4.17547402e-16 -4.19255090e-16 -3.39962267e-16
#   8.64916296e-17 -6.98325703e-17 -6.98325703e-17]

# %% [markdown]
# # Obtaining predictions for training dataset

# %%
predicted_values1= linear_model.intercept_ + linear_model.coef_ * X_train
print('predicted response:', predicted_values1, sep='\n')
predicted_values2 = linear_model.predict(X_train)
print('predicted response:', predicted_values2, sep='\n')
# Out:
# predicted response:
#        Appliances            T1          RH_1            T2          RH_2  \
# 9129     0.037383 -1.945227e-15 -1.473165e-15 -1.679383e-15 -2.182991e-15
# 2453     0.018692 -1.814591e-15 -1.302446e-15 -1.701893e-15 -2.283257e-15
# 9152     0.028037 -1.898852e-15 -1.477497e-15 -1.657121e-15 -2.222013e-15
# 12694    0.102804 -1.984418e-15 -1.327289e-15 -1.733144e-15 -2.316047e-15
# 16952    0.037383 -2.154246e-15 -1.344489e-15 -1.977868e-15 -1.944520e-15
# ...           ...           ...           ...           ...           ...
# 11284    0.046729 -1.962210e-15 -1.372390e-15 -1.718961e-15 -2.250738e-15
# 11964    0.102804 -2.003361e-15 -1.318881e-15 -1.783523e-15 -2.223007e-15
# 5390     0.018692 -1.866192e-15 -1.471764e-15 -1.689525e-15 -2.101694e-15
# 860      0.065421 -1.964170e-15 -1.474440e-15 -1.744786e-15 -2.034651e-15
# 15795    0.112150 -1.933688e-15 -1.432970e-15 -1.731330e-15 -2.128161e-15
#
# ...

# %% [markdown]
# # obtaining predictions for the testing dataset

# %%
predicted_values = linear_model.predict(X_test)
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, predicted_values)
round(mae,3)
# Out:
# 0.0

# %% [markdown]
# # Linear Regression results

# %%
rss = np.sum(np.square(y_test - predicted_values))  
#rss = sum((y_test-predicted_values)**2)
round(rss,3)
# Out:
# 42.334

# %%
from sklearn.metrics import mean_squared_error  
rmse   =   np.sqrt(mean_squared_error(y_test , predicted_values))  
round(rmse, 3)
# Out:
# 0.085

# %%
from    sklearn.metrics    import    r2_score  
r2_score   =   r2_score(y_test,   predicted_values)  
round(r2_score,    3)
# Out:
# 0.205

# %%
mse = np.mean((y_test -predicted_values)**2)
round(mse, 3)
# Out:
# 0.007

# %% [markdown]
# # Ridge Regression

# %%
ridge_reg = Ridge(alpha= 0.4, normalize=True)  
ridge_reg.fit(X_train, y_train)
ridge_reg = Ridge(alpha= 0.4, normalize=True).fit(X_train, y_train)
ridge_reg
# Out:
# Ridge(alpha=0.4, copy_X=True, fit_intercept=True, max_iter=None, normalize=True,
#       random_state=None, solver='auto', tol=0.001)

# %%
predicted_response = ridge_reg.predict(X_test)
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, predicted_response)
round(mae,3)
# Out:
# 0.018

# %%
rss = np.sum(np.square(y_test - predicted_response))  
#rss = sum((y_test - predicted_response)**2)
round(rss,3)
# Out:
# 5.856

# %%
from sklearn.metrics import mean_squared_error  
rmse   =   np.sqrt(mean_squared_error(y_test,   predicted_response))  
round(rmse, 3)
# Out:
# 0.031

# %%
mse = np.mean((y_test - predicted_response)**2)
round(mse,3)
# Out:
# 0.001

# %%
from    sklearn.metrics    import    r2_score  
r2_score   =   r2_score(y_test,   predicted_response)  
round(r2_score,    3)
# Out:
# 0.89

# %% [markdown]
# # Lasso Regression

# %%
lasso_reg = Lasso(alpha= 0.001, normalize=True)  
lasso_reg.fit(X_train, y_train)
lasso_reg = Lasso(alpha= 0.001, normalize=True).fit(X_train, y_train)
lasso_reg
# Out:
# Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=True, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
predicted_response2 = lasso_reg.predict(X_test)
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, predicted_response2)
round(mae,3)
# Out:
# 0.057

# %%
rss = np.sum(np.square(y_test - predicted_response2))  
#rss = sum((y_test, predicted_response)**2)
round(rss,3)
# Out:
# 53.281

# %%
from sklearn.metrics import mean_squared_error  
rmse   =   np.sqrt(mean_squared_error(y_test,   predicted_response2))  
round(rmse, 3)
# Out:
# 0.095

# %%
from    sklearn.metrics    import    r2_score  
r2_score   =   r2_score(y_test ,  predicted_response2)  
round(r2_score,    3)
# Out:
# -0.0

# %% [markdown]
# # comparing   the   effects   of   regularisation

# %%
def get_weights_df(model, feat, col_name): 
    weights   =   pd.Series(model.coef_,feat.columns).sort_values()     
    weights_df   =   pd.DataFrame(weights).reset_index()     
    weights_df.columns   =   [ 'Features' ,   col_name]     
    weights_df[col_name].round( 3 )      
    return    weights_df

# %%
linear_model_weights   =   get_weights_df(linear_model,   X_train, 'Linear_Model_Weight' )  
ridge_weights_df   =   get_weights_df(ridge_reg,   X_train, 'Ridge_Weight' )  
lasso_weights_df   =   get_weights_df(lasso_reg,   X_train,    'Lasso_weight' )

# %%
final_weights   =   pd.merge(linear_model_weights,   ridge_weights_df,   on= 'Features' )  
final_weights   =   pd.merge(final_weights,   lasso_weights_df,   on= 'Features' )
final_weights
# Out:
#        Features  Linear_Model_Weight  Ridge_Weight  Lasso_weight
# 0          RH_2        -9.637296e-16     -0.007254          -0.0
# 1          RH_8        -7.265496e-16     -0.015853          -0.0
# 2            T7        -6.513448e-16     -0.003850           0.0
# 3            T1        -6.185629e-16     -0.000717           0.0
# 4     Windspeed        -4.192551e-16      0.006343           0.0
# 5            T6        -3.670740e-16      0.006464           0.0
# 6            T2        -3.402895e-16      0.008612           0.0
# 7    Visibility        -3.399623e-16      0.001874           0.0
# 8            T5        -1.965324e-16     -0.006582           0.0
# 9          RH_4        -1.426087e-16      0.003000           0.0
# 10  Press_mm_hg        -1.188973e-16     -0.002157          -0.0
# 11          rv1        -6.983257e-17      0.000065          -0.0
# 12          rv2        -6.983257e-17      0.000065          -0.0
# ...
